# %% [markdown]
# # London Road Collision Severity (Showcase Notebook)
#
# This notebook is a presentation-oriented summary of the upgraded CASA0006 project.
# For reproducible pipelines and deployment, use the `src/` modules and Streamlit app.

# %% [markdown]
# ## 1) Load sample data

# %%
import pandas as pd
df = pd.read_csv('../data/sample/merged_sample.csv')
df.head()

# %% [markdown]
# ## 2) Check severity distribution

# %%
df['accident_severity'].value_counts(dropna=False).sort_index()

# %% [markdown]
# ## 3) Load model metrics artifact

# %%
import json
from pathlib import Path
metrics_path = Path('../artifacts/metrics.json')
if metrics_path.exists():
    metrics = json.loads(metrics_path.read_text(encoding='utf-8'))
    metrics['selected_model'], metrics['selected_model_metrics']
else:
    print('Run: python -m src.train --config configs/default.yaml')
